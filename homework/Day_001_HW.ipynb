# %% [markdown]
# # 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp) ** 2) / len(y)
    return mse

MSE = mean_squared_error(y, y_hat)

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 210.295
# The Mean absolute error is 11.412

# %% [markdown]
# ### 作業1：
# #### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# Aerial Cactus Identification
# Determine whether an image contains a columnar cactus
# https://www.kaggle.com/c/aerial-cactus-identification/overview
#
# #### 1. 你選的這組資料為何重要
# 起初在Competitions頁面看到這個比賽以為是基於「好玩」的心態發起的，識別出照片中是否有先仙人掌。
# 後來仔細看了一下內容才發覺是為了去觀察氣候變遷對動植物的影響，及「人類活動對自然環境的影響」。故對未來的環境生態研究與保護是至關重要的。
# 恩…不過這個是Kaggle官方舉辦給使用者娛樂與練習的。
# #### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 最原始資料是由研究人員J. Irving Vasquez-Gomez 於VIGIA project提供，資料蒐集的部分是由空拍機拍攝收集。
# #### 3. 蒐集而來的資料型態為何
# 非結構化資料: 圖像(.jpg)
# #### 4. 這組資料想解決的問題如何評估
# 預測照片中是否有柱狀仙人掌 => 有/沒有 => ROC

# %% [markdown]
# ### 作業2：
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 提升業績: 每臺車的月收入可以較以往提升(例如: 較以往提升10%的收入)。
# 假設收入與載客班數和車資有關，問題是「如何快速地找到客人、單趟車資較高的客人」。
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 乘客的歷史搭乘軌跡(上下車地點、行經路線)、搭乘時間(上下車)與車資: 司機記下交易紀錄，行經路線可由車上裝置GPS系統來記錄。
# #### 3. 蒐集而來的資料型態為何
# 一、搭乘軌跡、搭乘時間與車資: 結構化的數值表格
# 二、行經路線: 結構化的數值(一串經緯度)
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 從歷史的乘客搭乘軌跡來預測未來的活動，預測未來在某個時間與地點會有乘客需要搭車，應該是迴歸MAE。
